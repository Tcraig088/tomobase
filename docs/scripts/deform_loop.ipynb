# %%
import tomobase
from tomobase import phantoms, processes

vol = phantoms.get_nanocage()

for i in range(60):
   vol = processes.deformations.beamdamage(vol, 0.005, 0.05) 
   vol.to_file(f'tdtomo_example{i}.rec')
# Out:
# Running cells with 'napari-2 (Python 3.11.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n napari-2 ipykernel --update-deps --force-reinstall'
